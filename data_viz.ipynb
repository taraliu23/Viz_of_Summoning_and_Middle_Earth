# %%
import folium
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %%
my_map = folium.Map(
    location=[45.226494,4.508067],
    zoom_start=6
)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e9f01d5dff418a889782ccbbadead0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e9f01d5dff418a889782ccbbadead0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6e9f01d5dff418a889782ccbbadead0c = L.map(
#                 &quot;map_6e9f01d5dff418a889782ccbbadead0c&quot;,
#                 {
#                     center: [45.226494, 4.508067],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3907f934fdd61ed8da299d0421607a2b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6e9f01d5dff418a889782ccbbadead0c);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
poi = pd.read_csv('final_geo_data/csv/poi_wgs84_xy_cleared.csv')
poi.head(3)
# Out:
#                    Name         Type                          Inhabitant  \
# 0    Field of Celebrant        Field                                 NaN
# 1            Firienfeld  Flat upland                            Rohirrim
# 2  Plateau of Gorgoroth        Plain  Sauron, Orcs, Men allied to Sauron
#
#                                      English Westron Quenya  \
# 0  Field of Celebrant; Field of "Silverlode"     NaN    NaN
# 1                                  Dunharrow     NaN    NaN
# 2                  Plateau of "horror/dread"     NaN    NaN
#
#                  Sindarin Khuzdul    Rohirric Other    SHAPE_Leng  \
# 0    [field of] Celebrant     NaN         NaN   NaN  3.727657e+05
# 1                     NaN     NaN  Firienfeld   NaN  4.367542e+03
# 2  [plateau of] Gorgoroth     NaN         NaN   NaN  5.635612e+06
#
#      SHAPE_Area          x          y
# 0  2.598167e+09  48.686831   6.712481
# 1  1.376384e+06  45.530912   4.431309
# 2  3.640515e+10  43.736524  12.934796

# %%
folium.Marker(
    location=[49.4945077089,8.1286725884]
).add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e9f01d5dff418a889782ccbbadead0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e9f01d5dff418a889782ccbbadead0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6e9f01d5dff418a889782ccbbadead0c = L.map(
#                 &quot;map_6e9f01d5dff418a889782ccbbadead0c&quot;,
#                 {
#                     center: [45.226494, 4.508067],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3907f934fdd61ed8da299d0421607a2b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6e9f01d5dff418a889782ccbbadead0c);
#
#
#             var marker_7704cddccb8c0668422235a1cf34bc99 = L.marker(
#                 [49.4945077089, 8.1286725884],
#                 {}
#             ).addTo(map_6e9f01d5dff418a889782ccbbadead0c);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
test_poi = pd.read_excel('final_geo_data/csv/obvious_poi.xlsx')

df_ov_test_poi = test_poi.iloc[:, 0:10]

df_ov_test_poi
# Out:
#        referred_place                             album  album year  \
# 0          Dol Guldur                           Lugburz        1995
# 1        Minas Tirith                      Minas Morgul        1995
# 2               Erech                      Minas Morgul        1995
# 3     White Mountains                      Minas Morgul        1995
# 4            Morthond                      Minas Morgul        1995
# 5          Dol Guldur                      Minas Morgul        1995
# 6               Erech                        Dol Guldur        1997
# 7   Paths of the Dead                        Dol Guldur        1998
# 8     Lonely Mountain  Let Mortal Heroes Sing Your Fame        2001
# 9        Minas Tirith                 Old Mornings Dawn        2013
# 10          Caradhras                 Old Mornings Dawn        2013
#
#                           song title  \
# 0               Flight of the Nazgul
# 1    The Passing of the Grey Company
# 2    The Passing of the Grey Company
# 3    The Passing of the Grey Company
# 4                           Morthond
# 5   Through the Forest of Dol Guldur
# 6               Unto a Long Glory...
# 7               Unto a Long Glory...
# 8         The Mountain King's Return
# 9                    The White Tower
# 10                         Caradhras
#
#                                        related lyrics  \
# 0                                              Nazgul
# 1           To Minas Tirith White they’ve passed road
# 2   At the stone of Erech they shall hear a horn i...
# 3      Far away, covered by shadows, White Mountains,
# 4                                            Morthond
# 5   Dol Enshrined in silence and runes will keep\n...
# 6        At the stone of Erech they shall stand again
# 7                            To the Paths of the Dead
# 8                Mountain King(Thorin II Oakenshield)
# 9                                     The White Tower
# 10                                          Caradhras
#
#                                            other name      type  \
# 0   Hill of Dark Sorcery, Amon Lanc, the dungeons ...      hill
# 1   Tower of the Guard, Minas Anor, Mundburg, The ...      city
# 2   Northern Lamedon, south of the White Mountains...      hill
# 3                                        Ered Nimrais  mountain
# 4                                           Blackroot     river
# 5   Hill of Dark Sorcery, Amon Lanc, the dungeons ...      hill
# 6   Northern Lamedon, south of the White Mountains...      hill
# 7                                     Dwimorberg pass      pass
# 8                                              Erebor  mountain
# 9   Tower of the Guard, Minas Anor, Mundburg, The ...      city
# 10                                Redhorn, Barazinbar  mountain
#
#                                              location          x          y
# 0                                   Southern Mirkwood  49.494508   8.128673
# 1   Easternmost point of the White Mountains, clos...  44.125308   9.436244
# 2   Gondor, Northern Lamedon, south of the White M...  44.828908   4.738755
# 3                            Between Gondor and Rohan  42.771597  -0.489866
# 4   Gondor, in the province of Lamedon near the St...  44.308084   4.310990
# 5                                   Southern Mirkwood  49.494508   8.128673
# 6   \tNorthern Lamedon, south of the White Mountai...  44.828908   4.738755
# 7                         White Mountains, Dwimorberg  45.226494   4.508067
# 8                           \tNorth-east of Rhovanion  52.989497  10.791920
# 9   Easternmost point of the White Mountains, clos...  44.125308   9.436244
# 10  \tabove Khazad-dûm, between Celebdil and Fanui...  50.097028   4.127051

# %%
for i in range(len(df_ov_test_poi)):
    folium.Marker(
        location=[df_ov_test_poi.loc[i,'x'],df_ov_test_poi.loc[i,'y']],
        popup='album: ' + df_ov_test_poi.loc[i,'album'],
        tooltip='location: ' + df_ov_test_poi.loc[i,'referred_place']
    ).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e9f01d5dff418a889782ccbbadead0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e9f01d5dff418a889782ccbbadead0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6e9f01d5dff418a889782ccbbadead0c = L.map(
#                 &quot;map_6e9f01d5dff418a889782ccbbadead0c&quot;,
#                 {
#                     center: [45.226494, 4.508067],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3907f934fdd61ed8da299d0421607a2b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6e9f01d5dff418a889782ccbbadead0c);
#
#
#             var marker_7704cddccb8c0668422235a1cf34bc99 = L.marker(
#                 [49.4945077089, 8.1286725884],
#                 {}
#             ).addTo(map_6e9f01d5dff418a889782ccbbadead0c);
#
#
#             var marker_8cbb255e8d5caaa800cd2900a7b4bb7c = L.marker(
#                 [49.4945077, 8.1286726],
#                 {}
#             ).addTo(map_6e9f01d5dff418a889782ccbbadead0c);
#
#
#         var popup_df4dce907ac3de5097d51405eca8c8f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1e33123ea083855b2574047e5bad9067 = $(`&lt;div id=&quot;html_1e33123ea083855b2574047e5bad9067&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;album: Lugburz&lt;/div&gt;`)[0];
#             popup_df4dce907ac3de5097d51405eca8c8f8.setContent(html_1e33123ea083855b2574047e5bad9067);
#
#
#         marker_8cbb255e8d5caaa800cd2900a7b4bb7c.bindPopup(popup_df4dce907ac3de5097d51405eca8c8f8)
#         ;
#
#
#
#
#             marker_8cbb255e8d5caaa800cd2900a7b4bb7c.bindTooltip(
#                 `&lt;div&gt;
#                      location: Dol Guldur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_000704a8c50cb9a6ea1a522b8f56767a = L.marker(
#                 [44.1253076399, 9.436243953],
#                 {}
#             ).addTo(map_6e9f01d5dff418a889782ccbbadead0c);
#
#
#         var popup_6681616bc15728c231b0907c5df7facf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_90e324b7c17b78a4e27f8be6c47af8dc = $(`&lt;div id=&quot;html_90e324b7c17b78a4e27f8be6c47af8dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;album: Minas Morgul&lt;/div&gt;`)[0];
#             popup_6681616bc15728c231b0907c5df7facf.setContent(html_90e324b7c17b78a4e27f8be6c47af8dc);
#
#
#         marker_000704a8c50cb9a6ea1a522b8f56767a.bindPopup(popup_6681616bc15728c231b0907c5df7facf)
#         ;
#
#
#
#
#             marker_000704a8c50cb9a6ea1a522b8f56767a.bindTooltip(
#                 `&lt;div&gt;
#                      location: Minas Tirith
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1c553f801e3304e5e6ae116efa8c9a5c = L.marker(
#                 [44.8289080134, 4.7387549269],
#                 {}
#             ).addTo(map_6e9f01d5dff418a889782ccbbadead0c);
#
#
#         var popup_80eaaba9f2769ed952f0149feb276cee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d9c93c14d25b3d8f45b1ee150a472928 = $(`&lt;div id=&quot;html_d9c93c14d25b3d8f45b1ee150a472928&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;album: Minas Morgul&lt;/div&gt;`)[0];
#             popup_80eaaba9f2769ed952f0149feb276cee.setContent(html_d9c93c14d25b3d8f45b1ee150a472928);
#
#
#         marker_1c553f801e3304e5e6ae116efa8c9a5c.bindPopup(popup_80eaaba9f2769ed952f0149feb276cee)
#         ;
#
#
#
#
#             marker_1c553f801e3304e5e6ae116efa8c9a5c.bindTooltip(
#                 `&lt;div&gt;
#                      location: Erech
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8131967d72467599f5e6e463d7bda012 = L.marker(
#                 [42.7715974269, -0.4898657755],
#                 {}
#             ).addTo(map_6e9f01d5dff418a889782ccbbadead0c);
#
#
#         var popup_cbe4ffde92209ee953efc2f818e7998e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_509a276cd9d4448e23ef25814dc20463 = $(`&lt;div id=&quot;html_509a276cd9d4448e23ef25814dc20463&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;album: Minas Morgul&lt;/div&gt;`)[0];
#             popup_cbe4ffde92209ee953efc2f818e7998e.setContent(html_509a276cd9d4448e23ef25814dc20463);
#
#
#         marker_8131967d72467599f5e6e463d7bda012.bindPopup(popup_cbe4ffde92209ee953efc2f818e7998e)
#         ;
#
#
#
#
#             marker_8131967d72467599f5e6e463d7bda012.bindTooltip(
#                 `&lt;div&gt;
#                      location: White Mountains
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}

# %%
# try to use geopandas to save time

# csv to geodf
from fileinput import filename
from socket import create_server

geome = gpd.points_from_xy(df_ov_test_poi['y'],df_ov_test_poi['x'])
gdf = gpd.GeoDataFrame(df_ov_test_poi, geometry = geome, crs=4326)
type(gdf)

# gdf.to_file(filename='test_poi_for_ite_map', driver='ESRI Shapefile', crs=4326)

# geodf to interactive map
gdf.explore(tiles='Stamen Watercolor', popup=False, marker_type='marker', highlight_kwds= {"fillOpacity": 0.3})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5bfc8618e5afc5f57df8eafc8743fc56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5bfc8618e5afc5f57df8eafc8743fc56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5bfc8618e5afc5f57df8eafc8743fc56 = L.map(
#                 &quot;map_5bfc8618e5afc5f57df8eafc8743fc56&quot;,
#                 {
#                     center: [47.88054701585, 5.15102710925],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5bfc8618e5afc5f57df8eafc8743fc56);
#
#
#
#
#
#             var tile_layer_9a65b7520a0d2e4a3e0a966b5a704ae6 = L.tileLayer(
#                 &quot;https://stamen-tiles-a.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e \u0026mdash; Map data \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 16, &quot;maxZoom&quot;: 16, &quot;minZoom&quot;: 1, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5bfc8618e5afc5f57df8eafc8743fc56);
#
#
#             map_5bfc8618e5afc5f57df8eafc8743fc56.fitBounds(
#                 [[42.7715974269, -0.4898657755], [52.9894966048, 10.791919994]],
#                 {}
#             );
#
#
#         function geo_json_6876d1a72f930ab4a25bd1f3528984f1_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_6876d1a72f930ab4a25bd1f3528984f1_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.3};
#             }
#         }
#         function geo_json_6876d1a72f930ab4a25bd1f3528984f1_pointToLayer(feature, latlng) {
#             var opts = {&quot;fill&quot;: true, &quot;radius&quot;: 2};
#
#             let style = geo_json_6876d1a72f930ab4a25bd1f3528984f1_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_6876d1a72f930ab4a25bd1f3528984f1_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_6876d1a72f930ab4a25bd1f3528984f1.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_6876d1a72f930ab4a25bd1f3528984f1_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_6876d1a72f930ab4a25bd1f3528984f1 = L.geoJson(null, {
#                 onEachFeature: geo_json_6876d1a72f930ab4a25bd1f3528984f1_onEachFeature,
#
#                 style: geo_json_6876d1a72f930ab4a25bd1f3528984f1_styler,
#                 pointToLayer: geo_json_6876d1a72f930ab4a25bd1f3528984f1_pointToLayer
#         });
#
#         function geo_json_6876d1a72f930ab4a25bd1f3528984f1_add (data) {
#             geo_json_6876d1a72f930ab4a25bd1f3528984f1
#                 .addData(data)
#                 .addTo(map_5bfc8618e5afc5f57df8eafc8743fc56);
#         }
#             geo_json_6876d1a72f930ab4a25bd1f3528984f1_add({&quot;bbox&quot;: [-0.4898657755, 42.7715974269, 10.791919994, 52.9894966048], &quot;features&quot;: [{&quot;bbox&quot;: [8.1286726, 49.4945077, 8.1286726, 49.4945077], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.1286726, 49.4945077], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;album&quot;: &quot;Lugburz&quot;, &quot;album year&quot;: 1995, &quot;location&quot;: &quot;Southern Mirkwood&quot;, &quot;other name&quot;: &quot;Hill of Dark Sorcery, Amon Lanc, the dungeons of the Necromancer&quot;, &quot;referred_place&quot;: &quot;Dol Guldur&quot;, &quot;related lyrics&quot;: &quot;Nazgul&quot;, &quot;song title&quot;: &quot;Flight of the Nazgul&quot;, &quot;type&quot;: &quot;hill&quot;, &quot;x&quot;: 49.4945077, &quot;y&quot;: 8.1286726}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [9.436243953, 44.1253076399, 9.436243953, 44.1253076399], &quot;geometry&quot;: {&quot;coordinates&quot;: [9.436243953, 44.1253076399], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;
