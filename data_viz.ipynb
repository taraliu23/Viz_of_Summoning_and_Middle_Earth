# %%
import folium
import pandas as pd
import geopandas as gpd

# %%
my_map = folium.Map(
    location=[45.226494,4.508067],
    zoom_start=6
)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eaac7c1d1d6bd92b456d2b9c4e64d8dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eaac7c1d1d6bd92b456d2b9c4e64d8dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_eaac7c1d1d6bd92b456d2b9c4e64d8dd = L.map(
#                 &quot;map_eaac7c1d1d6bd92b456d2b9c4e64d8dd&quot;,
#                 {
#                     center: [45.226494, 4.508067],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a87798ca8ab8692fc601d58709f909b1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eaac7c1d1d6bd92b456d2b9c4e64d8dd);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
poi = pd.read_csv('final_geo_data/csv/poi_wgs84_xy_cleared.csv')
poi.head(3)
# Out:
#                    Name         Type                          Inhabitant  \
# 0    Field of Celebrant        Field                                 NaN
# 1            Firienfeld  Flat upland                            Rohirrim
# 2  Plateau of Gorgoroth        Plain  Sauron, Orcs, Men allied to Sauron
#
#                                      English Westron Quenya  \
# 0  Field of Celebrant; Field of "Silverlode"     NaN    NaN
# 1                                  Dunharrow     NaN    NaN
# 2                  Plateau of "horror/dread"     NaN    NaN
#
#                  Sindarin Khuzdul    Rohirric Other    SHAPE_Leng  \
# 0    [field of] Celebrant     NaN         NaN   NaN  3.727657e+05
# 1                     NaN     NaN  Firienfeld   NaN  4.367542e+03
# 2  [plateau of] Gorgoroth     NaN         NaN   NaN  5.635612e+06
#
#      SHAPE_Area          x          y
# 0  2.598167e+09  48.686831   6.712481
# 1  1.376384e+06  45.530912   4.431309
# 2  3.640515e+10  43.736524  12.934796

# %%
folium.Marker(
    location=[49.4945077089,8.1286725884]
).add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eaac7c1d1d6bd92b456d2b9c4e64d8dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eaac7c1d1d6bd92b456d2b9c4e64d8dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_eaac7c1d1d6bd92b456d2b9c4e64d8dd = L.map(
#                 &quot;map_eaac7c1d1d6bd92b456d2b9c4e64d8dd&quot;,
#                 {
#                     center: [45.226494, 4.508067],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a87798ca8ab8692fc601d58709f909b1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eaac7c1d1d6bd92b456d2b9c4e64d8dd);
#
#
#             var marker_f90d674181b11ab46b9a79c2cf2db3d5 = L.marker(
#                 [49.4945077089, 8.1286725884],
#                 {}
#             ).addTo(map_eaac7c1d1d6bd92b456d2b9c4e64d8dd);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
test_poi = pd.read_excel('final_geo_data/csv/obvious_poi.xlsx')

df_ov_test_poi = test_poi.iloc[:, 0:10]

df_ov_test_poi
# Out:
#        referred_place                             album  album year  \
# 0          Dol Guldur                           Lugburz        1995
# 1        Minas Tirith                      Minas Morgul        1995
# 2               Erech                      Minas Morgul        1995
# 3     White Mountains                      Minas Morgul        1995
# 4            Morthond                      Minas Morgul        1995
# 5          Dol Guldur                      Minas Morgul        1995
# 6               Erech                        Dol Guldur        1997
# 7   Paths of the Dead                        Dol Guldur        1998
# 8     Lonely Mountain  Let Mortal Heroes Sing Your Fame        2001
# 9        Minas Tirith                 Old Mornings Dawn        2013
# 10          Caradhras                 Old Mornings Dawn        2013
#
#                           song title  \
# 0               Flight of the Nazgul
# 1    The Passing of the Grey Company
# 2    The Passing of the Grey Company
# 3    The Passing of the Grey Company
# 4                           Morthond
# 5   Through the Forest of Dol Guldur
# 6               Unto a Long Glory...
# 7               Unto a Long Glory...
# 8         The Mountain King's Return
# 9                    The White Tower
# 10                         Caradhras
#
#                                        related lyrics  \
# 0                                              Nazgul
# 1           To Minas Tirith White they’ve passed road
# 2   At the stone of Erech they shall hear a horn i...
# 3      Far away, covered by shadows, White Mountains,
# 4                                            Morthond
# 5   Dol Enshrined in silence and runes will keep\n...
# 6        At the stone of Erech they shall stand again
# 7                            To the Paths of the Dead
# 8                Mountain King(Thorin II Oakenshield)
# 9                                     The White Tower
# 10                                          Caradhras
#
#                                            other name      type  \
# 0   Hill of Dark Sorcery, Amon Lanc, the dungeons ...      hill
# 1   Tower of the Guard, Minas Anor, Mundburg, The ...      city
# 2   Northern Lamedon, south of the White Mountains...      hill
# 3                                        Ered Nimrais  mountain
# 4                                           Blackroot     river
# 5   Hill of Dark Sorcery, Amon Lanc, the dungeons ...      hill
# 6   Northern Lamedon, south of the White Mountains...      hill
# 7                                     Dwimorberg pass      pass
# 8                                              Erebor  mountain
# 9   Tower of the Guard, Minas Anor, Mundburg, The ...      city
# 10                                Redhorn, Barazinbar  mountain
#
#                                              location          x          y
# 0                                   Southern Mirkwood  49.494508   8.128673
# 1   Easternmost point of the White Mountains, clos...  44.125308   9.436244
# 2   Gondor, Northern Lamedon, south of the White M...  44.828908   4.738755
# 3                            Between Gondor and Rohan  42.771597  -0.489866
# 4   Gondor, in the province of Lamedon near the St...  44.308084   4.310990
# 5                                   Southern Mirkwood  49.494508   8.128673
# 6   \tNorthern Lamedon, south of the White Mountai...  44.828908   4.738755
# 7                         White Mountains, Dwimorberg  45.226494   4.508067
# 8                           \tNorth-east of Rhovanion  52.989497  10.791920
# 9   Easternmost point of the White Mountains, clos...  44.125308   9.436244
# 10  \tabove Khazad-dûm, between Celebdil and Fanui...  50.097028   4.127051

# %%
for i in range(len(df_ov_test_poi)):
    folium.Marker(
        location=[df_ov_test_poi.loc[i,'x'],df_ov_test_poi.loc[i,'y']],
        popup='album: ' + df_ov_test_poi.loc[i,'album'],
        tooltip='location: ' + df_ov_test_poi.loc[i,'referred_place']
    ).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eaac7c1d1d6bd92b456d2b9c4e64d8dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eaac7c1d1d6bd92b456d2b9c4e64d8dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_eaac7c1d1d6bd92b456d2b9c4e64d8dd = L.map(
#                 &quot;map_eaac7c1d1d6bd92b456d2b9c4e64d8dd&quot;,
#                 {
#                     center: [45.226494, 4.508067],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a87798ca8ab8692fc601d58709f909b1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eaac7c1d1d6bd92b456d2b9c4e64d8dd);
#
#
#             var marker_f90d674181b11ab46b9a79c2cf2db3d5 = L.marker(
#                 [49.4945077089, 8.1286725884],
#                 {}
#             ).addTo(map_eaac7c1d1d6bd92b456d2b9c4e64d8dd);
#
#
#             var marker_69c3b4da9e2561edaf45468a8e72a42c = L.marker(
#                 [49.4945077, 8.1286726],
#                 {}
#             ).addTo(map_eaac7c1d1d6bd92b456d2b9c4e64d8dd);
#
#
#         var popup_8c895bdeba36f3861e8750bf827adc82 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cffecbf2ef7d9333e1c0e62e7e9e88fe = $(`&lt;div id=&quot;html_cffecbf2ef7d9333e1c0e62e7e9e88fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;album: Lugburz&lt;/div&gt;`)[0];
#             popup_8c895bdeba36f3861e8750bf827adc82.setContent(html_cffecbf2ef7d9333e1c0e62e7e9e88fe);
#
#
#         marker_69c3b4da9e2561edaf45468a8e72a42c.bindPopup(popup_8c895bdeba36f3861e8750bf827adc82)
#         ;
#
#
#
#
#             marker_69c3b4da9e2561edaf45468a8e72a42c.bindTooltip(
#                 `&lt;div&gt;
#                      location: Dol Guldur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e989eeb2e9446d7b49386f9215cc114b = L.marker(
#                 [44.1253076399, 9.436243953],
#                 {}
#             ).addTo(map_eaac7c1d1d6bd92b456d2b9c4e64d8dd);
#
#
#         var popup_075d13b044f863b7a4f7f4efa06ac5b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d2a450b54dd79af23618eba7a5943d20 = $(`&lt;div id=&quot;html_d2a450b54dd79af23618eba7a5943d20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;album: Minas Morgul&lt;/div&gt;`)[0];
#             popup_075d13b044f863b7a4f7f4efa06ac5b7.setContent(html_d2a450b54dd79af23618eba7a5943d20);
#
#
#         marker_e989eeb2e9446d7b49386f9215cc114b.bindPopup(popup_075d13b044f863b7a4f7f4efa06ac5b7)
#         ;
#
#
#
#
#             marker_e989eeb2e9446d7b49386f9215cc114b.bindTooltip(
#                 `&lt;div&gt;
#                      location: Minas Tirith
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2e3b1ce057eb8c7826c242de6efa192a = L.marker(
#                 [44.8289080134, 4.7387549269],
#                 {}
#             ).addTo(map_eaac7c1d1d6bd92b456d2b9c4e64d8dd);
#
#
#         var popup_cb4b576006edc552e939709e936c0091 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_730ab7544799ccfb884b19cca88fc659 = $(`&lt;div id=&quot;html_730ab7544799ccfb884b19cca88fc659&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;album: Minas Morgul&lt;/div&gt;`)[0];
#             popup_cb4b576006edc552e939709e936c0091.setContent(html_730ab7544799ccfb884b19cca88fc659);
#
#
#         marker_2e3b1ce057eb8c7826c242de6efa192a.bindPopup(popup_cb4b576006edc552e939709e936c0091)
#         ;
#
#
#
#
#             marker_2e3b1ce057eb8c7826c242de6efa192a.bindTooltip(
#                 `&lt;div&gt;
#                      location: Erech
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4d442f41ee9c041f607f39bcda6fc9a8 = L.marker(
#                 [42.7715974269, -0.4898657755],
#                 {}
#             ).addTo(map_eaac7c1d1d6bd92b456d2b9c4e64d8dd);
#
#
#         var popup_40c9b0de6837e1cdc21442041e00db9c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b171fd7aaefcd1c526376caa7b223e43 = $(`&lt;div id=&quot;html_b171fd7aaefcd1c526376caa7b223e43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;album: Minas Morgul&lt;/div&gt;`)[0];
#             popup_40c9b0de6837e1cdc21442041e00db9c.setContent(html_b171fd7aaefcd1c526376caa7b223e43);
#
#
#         marker_4d442f41ee9c041f607f39bcda6fc9a8.bindPopup(popup_40c9b0de6837e1cdc21442041e00db9c)
#         ;
#
#
#
#
#             marker_4d442f41ee9c041f607f39bcda6fc9a8.bindTooltip(
#                 `&lt;div&gt;
#                      location: White Mountains
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
