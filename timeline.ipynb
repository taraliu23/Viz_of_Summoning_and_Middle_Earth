# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fa = ax.broken_barh([(4500, 1040)], (24, 4),facecolors='tab:green') 
sa = ax.broken_barh([(5540, 3441)], (30, 4),facecolors='tab:green') 
ta = ax.broken_barh([(8981, 3021)], (36, 4),facecolors='tab:orange') 
fva = ax.broken_barh([(12002, 2000)], (42, 4)) 

v = ax.broken_barh([(0, 3500)],(6, 4))
t = ax.broken_barh([(3500, 1500)], (12, 4),
               )
s = ax.broken_barh([(5000, 14002)],(18, 4)) 
# fa = ax.broken_barh([4500, 490], (24, 4))              
ax.set_ylim(4, 48)
ax.set_xlim(0, 14000)
ax.set_xlabel('Years of Arda')
ax.set_xticks([0,3500,5000,12002,8981, 14000], labels=['YV1','YV3500','YT1500','TA3021','TA1','Unknown'])
ax.set_yticks([8, 14, 20, 26, 32, 38, 44], labels=['Year of the Valar', 'Year of the Tree', 'Year of the Sun', 'First Age', 'Second Age', 'Third Age', 'Fourth Age'])    
ax.grid(True, axis='x', color='0.8')  
               
plt.style.use('seaborn-colorblind')
# plt.show()

plt.savefig('timeline_1.png', dpi=500, bbox_inches = 'tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager

font_path_1 ='fonts/morris-roman/MorrisRomanAlternate-Black.ttf'
font_path_2 = 'fonts/aniron/anirm___.ttf'
font_manager.fontManager.addfont(font_path_1)
prop = font_manager.FontProperties(fname=font_path_1)

plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = prop.get_name()

fig, ax = plt.subplots()

fa = ax.broken_barh([(4500, 1040)], (24, 4),facecolors='tab:green') 
sa = ax.broken_barh([(5540, 3441)], (30, 4),facecolors='tab:green') 
ta = ax.broken_barh([(8981, 3021)], (36, 4),facecolors='tab:orange') 
fva = ax.broken_barh([(12002, 2000)], (42, 4)) 

v = ax.broken_barh([(0, 3500)],(6, 4))
t = ax.broken_barh([(3500, 1500)], (12, 4),
               )
s = ax.broken_barh([(5000, 14002)],(18, 4)) 
# fa = ax.broken_barh([4500, 490], (24, 4))              
ax.set_ylim(4, 48)
ax.set_xlim(0, 14000)
ax.set_xlabel('Years of Arda')
ax.set_xticks([0,3500,5000,12002,8981, 14000], labels=['YV1','YV3500','YT1500','TA3021','TA1','Unknown'])
ax.set_yticks([8, 14, 20, 26, 32, 38, 44], labels=['Year of the Valar', 'Year of the Tree', 'Year of the Sun', 'First Age', 'Second Age', 'Third Age', 'Fourth Age'])    
ax.grid(True, axis='x', color='0.8')  
               
plt.style.use('seaborn-deep')
# plt.show()

plt.savefig('timeline_3.png', dpi=500, bbox_inches = 'tight')

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager

# set a cute font!
font_path_1 ='fonts/morris-roman/MorrisRomanAlternate-Black.ttf'
font_path_2 = 'fonts/aniron/anirm___.ttf'
font_manager.fontManager.addfont(font_path_1)
prop = font_manager.FontProperties(fname=font_path_1)
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = prop.get_name()

# set ax with only two spines
fig, ax = plt.subplots()
ax.patch.set_facecolor('None')
ax.spines.bottom.set_color('0.2')
ax.spines.left.set_color('0.2')

# set gantt-chart-like broken barh
fa = ax.broken_barh([(4500, 1040)], (24, 4), facecolors='tab:purple') 
sa = ax.broken_barh([(5540, 3441)], (30, 4), facecolors='tab:purple') 
ta = ax.broken_barh([(8981, 3021)], (36, 4), facecolors='tab:cyan') 
fva = ax.broken_barh([(12002, 2200)], (42, 4), facecolors='tab:grey') 
v = ax.broken_barh([(0, 3500)],(6, 4),facecolors='tab:pink')
t = ax.broken_barh([(3500, 1500)], (12, 4),facecolors='tab:brown')
s = ax.broken_barh([(5000, 14002)],(18, 4),facecolors='tab:olive') 

# customize fig and ax      
ax.set_ylim(4, 47)
ax.set_xlim(0, 14200)
plt.title("HISTORY OF ARDA", fontsize=18, color='0')
ax.set_xlabel('Timeline',fontsize=18, color='0.1')
ax.set_ylabel('Years or Ages',fontsize=18, color='0.1')
ax.set_xticks([0,3500,5000,12002,8981, 14000], labels=['YV1','YV3500','YT1500','TA3021','TA1','Unknown...'],fontsize=10)
ax.set_yticks([8, 14, 20, 26, 32, 38, 44], labels=['Year of the Valar', 'Year of the Tree', 'Year of the Sun', 'First Age', 'Second Age', 'Third Age', 'Fourth Age'],fontsize=9)    
ax.tick_params(axis='both', colors='0.2')
ax.grid(True, axis='x', color='0.7', linestyle = ':')
ax.grid(True, axis='y', color='0.8', linestyle = ':')
              
#plt.show() # <- use this to check
plt.savefig('timeline_8.png', dpi=500, bbox_inches = 'tight') # <- use this to save
